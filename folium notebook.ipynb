# %%
import folium

# %%
playas = folium.Map(location=[10.410832, -75.903843], zoom_start=5)

# %%
playas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
folium.Marker(location=[10.2952, -75.5888], popup="Analisis de Sentimientos TripAdvisor: 2.75 / 5", tooltip="Playa Blanca (click para analisis de sentimientos)", icon=folium.Icon(color="blue")).add_to(playas)
folium.Marker(location=[10.3525 , -75.5758], popup="Analisis de Sentimientos TripAdvisor: 3.3 / 5", tooltip="Playas Tierra Bomba (click para analisis de sentimientos)", icon=folium.Icon(color="red")).add_to(playas)
folium.Marker(location=[11.2187127 , -74.2382051], popup="Analisis de Sentimientos TripAdvisor: 3.05 / 5", tooltip="Playa Blanca (click para analisis de sentimientos)", icon=folium.Icon(color="red")).add_to(playas)
folium.Marker(location=[12.195475 , -72.147218], popup="Analisis de Sentimientos TripAdvisor: 4.5 / 5", tooltip="Cabo de la Vela (click para analisis de sentimientos)", icon=folium.Icon(color="blue")).add_to(playas)
folium.Marker(location=[11.3251 , -74.0764], popup="Analisis de Sentimientos TripAdvisor: 3.95 / 5", tooltip="Playa Cristal (click para analisis de sentimientos)", icon=folium.Icon(color="blue")).add_to(playas)
folium.Marker(location=[11.2165 , -73.3989], popup="Analisis de Sentimientos TripAdvisor: 3.2 / 5", tooltip="Palomino (click para analisis de sentimientos)", icon=folium.Icon(color="red")).add_to(playas)
folium.Marker(location=[12.530099 , -81.708125], popup="Analisis de Sentimientos TripAdvisor: 4.05 / 5", tooltip="Playa San Luis (click para analisis de sentimientos)", icon=folium.Icon(color="blue")).add_to(playas)
folium.Marker(location=[12.599826  , -81.690615], popup="Analisis de Sentimientos TripAdvisor: 3.15 / 5", tooltip="Johnny Cay (click para analisis de sentimientos)", icon=folium.Icon(color="red")).add_to(playas)

# %%
playas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
